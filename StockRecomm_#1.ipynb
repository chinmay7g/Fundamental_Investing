# %% [markdown]
# # Stock Recommendation System

# %%
#importing libraries

import pandas as pd
from bs4 import BeautifulSoup as bs
import requests

# %%
# parsing data

def fundamental_metric(soup, metric):
    return soup.find(text= metric).find_next(class_='snapshot-td2').text

def get_fundamental_data(df):
    for symbol in df.index:
        
        try:
            url = ('https://finviz.com/quote.ashx?t=' + symbol.lower())
            soup = bs(requests.get(url, headers={'User-Agent': 'Mozilla/5.0'}).content)
            
            for m in df.columns:
                df.loc[symbol,m] = fundamental_metric(soup,m)
        except Exception as e:
            print(symbol, 'not found')
            
    return df

# %%
#getting list of stocks from SP500

sp500_list = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')

first_table = sp500_list[0]

# %%
first_table.head()
# Out:
#   Symbol             Security SEC filings             GICS Sector  \
# 0    MMM           3M Company     reports             Industrials
# 1    ABT  Abbott Laboratories     reports             Health Care
# 2   ABBV          AbbVie Inc.     reports             Health Care
# 3   ABMD          ABIOMED Inc     reports             Health Care
# 4    ACN        Accenture plc     reports  Information Technology
#
#                 GICS Sub Industry    Headquarters Location Date first added  \
# 0        Industrial Conglomerates      St. Paul, Minnesota       1976-08-09
# 1           Health Care Equipment  North Chicago, Illinois       1964-03-31
# 2                 Pharmaceuticals  North Chicago, Illinois       2012-12-31
# 3           Health Care Equipment   Danvers, Massachusetts       2018-05-31
# 4  IT Consulting & Other Services          Dublin, Ireland       2011-07-06
#
#        CIK      Founded
# 0    66740         1902
# 1     1800         1888
# 2  1551152  2013 (1888)
# 3   815094         1981
# 4  1467373         1989

# %%
# extracting all lists of only information technology companies

df = first_table[first_table['GICS Sector'] == 'Information Technology']

#information on new dataset

print(df.shape)

#extracting information

tickers = df['Symbol'].values.tolist()
# Out:
# (71, 9)

# %% [markdown]
# ### Stock Tickers

# %%
print(tickers)
# Out:
# ['ACN', 'ADBE', 'AMD', 'AKAM', 'APH', 'ADI', 'ANSS', 'AAPL', 'AMAT', 'ANET', 'ADSK', 'ADP', 'AVGO', 'BR', 'CDNS', 'CDW', 'CSCO', 'CTXS', 'CTSH', 'GLW', 'DXC', 'FFIV', 'FIS', 'FISV', 'FLT', 'FLIR', 'FTNT', 'IT', 'GPN', 'HPE', 'HPQ', 'INTC', 'IBM', 'INTU', 'IPGP', 'JKHY', 'JNPR', 'KEYS', 'KLAC', 'LRCX', 'LDOS', 'MA', 'MXIM', 'MCHP', 'MU', 'MSFT', 'MSI', 'NTAP', 'NLOK', 'NVDA', 'ORCL', 'PAYX', 'PAYC', 'PYPL', 'QRVO', 'QCOM', 'CRM', 'STX', 'NOW', 'SWKS', 'SNPS', 'TEL', 'TXN', 'TYL', 'VRSN', 'V', 'WDC', 'WU', 'XRX', 'XLNX', 'ZBRA']

# %% [markdown]
# ### Metrics for analysis

# %%
metric = ['P/B',
'P/E',
'Forward P/E',
'PEG',
'Debt/Eq',
'EPS (ttm)',
'Dividend %',
'ROE',
'ROI']

# %%
## Initializing Pandas DataFrame

data = pd.DataFrame(index=tickers, columns=metric)

data = get_fundamental_data(data)

data.head()
# Out:
#         P/B     P/E Forward P/E    PEG Debt/Eq EPS (ttm) Dividend %     ROE  \
# ACN    9.54   31.29       29.63   4.09    0.00      7.68      1.33%  32.40%
# ADBE  22.00   65.59       44.66   4.20    0.38      7.59          -  35.10%
# AMD   27.99  156.92       47.66   4.38    0.21      0.50          -  21.50%
# AKAM   4.53   32.99       19.88   2.98    0.00      3.30          -  14.70%
# APH    6.78   30.20       27.44  10.07    0.79      3.59      0.92%  24.70%
#
#          ROI
# ACN   33.90%
# ADBE  20.60%
# AMD   12.40%
# AKAM   9.00%
# APH   15.60%

# %% [markdown]
# ### Parsing strings to data numeric

# %%
data['Dividend %'] = data['Dividend %'].str.replace('%', '')
data['ROE'] = data['ROE'].str.replace('%','')
data['ROI'] = data['ROI'].str.replace('%','')

data = data.apply(pd.to_numeric, errors='coerce')
data
# Out:
#          P/B      P/E  Forward P/E     PEG  Debt/Eq  EPS (ttm)  Dividend %  \
# ACN     9.54    31.29        29.63    4.09     0.00       7.68        1.33
# ADBE   22.00    65.59        44.66    4.20     0.38       7.59         NaN
# AMD    27.99   156.92        47.66    4.38     0.21       0.50         NaN
# AKAM    4.53    32.99        19.88    2.98     0.00       3.30         NaN
# APH     6.78    30.20        27.44   10.07     0.79       3.59        0.92
# ADI     3.63    38.84        20.92    4.60     0.47       2.99        2.14
# ANSS    8.18    71.54        47.50   10.08     0.12       4.59         NaN
# AAPL   27.58    35.13        29.88    2.82     1.57       3.29        0.71
# AMAT    5.47    16.61        12.46    0.83     0.57       3.44        1.54
# ANET    5.15    21.97        21.36    3.26     0.00       9.39         NaN
# ADSK  760.87   140.82        44.06    4.26    24.31       1.68         NaN
# ADP    10.21    24.10        22.98    2.28     0.35       5.68        2.66
# AVGO    6.14    68.77        14.44    8.71     1.92       5.34        3.54
# BR     11.58    34.24        22.65    3.42     1.33       3.96        1.70
# CDNS   12.76    28.97        38.38    2.11     0.31       3.63         NaN
# CDW    15.41    22.37        18.03    2.46     3.69       5.11        1.33
# CSCO    4.53    15.40        12.19    2.49     0.38       2.64        3.55
# CTXS     NaN    22.97        21.92    2.45      NaN       5.92        1.03
# CTSH    3.46    23.71        17.70    8.41     0.22       2.96        1.25
# GLW     2.56   324.95        18.47   67.70     0.80       0.10        2.68
# DXC     1.08      NaN         4.77     NaN     2.62     -22.47         NaN
# FFIV    3.44    22.82        12.46   17.55     0.18       5.33         NaN
# FIS     1.87  1614.13        22.14  128.75     0.41       0.09        0.94
# FISV    2.13    80.02        18.65    4.65     0.69       1.26         NaN
# FLT     6.57    27.02        18.09    3.24     1.50       8.60         NaN
# FLIR    2.77    33.72        15.74    5.62     0.49       1.05        1.92
# FTNT   35.07    49.75        34.29    2.74     0.00       2.38         NaN
# IT     12.09    50.64        38.47    7.45     1.99       2.65         NaN
# GPN     1.89   117.39        21.74    7.90     0.35       1.48        0.45
# HPE     0.74   116.00         6.31     NaN     1.20       0.08        5.17
# ...      ...      ...          ...     ...      ...        ...         ...
# MA     52.66    47.10        38.96    4.21     0.00       7.20        0.47
# MXIM   10.79    27.83        24.79    4.62     0.00       2.41        2.86
# MCHP    4.67    41.46        15.53    5.92     1.70       2.50        1.42
# MU      1.44    24.52        11.82     NaN     0.18       2.00         NaN
# MSFT   13.38    36.22        28.46    2.38     0.62       5.76        0.98
# MSI      NaN    32.69        18.20    3.17      NaN       4.80        1.63
# NTAP   35.18    13.11        11.33    3.36     9.79       3.46        4.23
# NLOK     NaN    19.66        13.88    3.93      NaN       1.08        2.36
# NVDA   23.00    95.28        47.17    5.46     0.00       5.45        0.12
# ORCL   15.59    19.11        13.34    2.08     5.93       3.19        1.58
# PAYX   10.17    25.94        26.29    7.91     0.29       3.04        3.14
# PAYC   27.51    92.87        67.57    5.18     0.05       3.02         NaN
# PYPL   12.37    85.37        40.87    3.65     0.00       2.18         NaN
# QRVO    3.42    39.21        16.45    3.44     0.43       3.32         NaN
# QCOM   39.79    49.29        18.20    1.84     4.82       2.37        2.23
# CRM     5.92   645.33        66.95   33.12     0.00       0.39         NaN
# STX     6.86    12.49         9.01    1.59     2.34       3.79        5.49
# NOW    36.57   129.43        86.73    4.59     0.00       3.66         NaN
# SWKS    5.63    30.66        20.38    2.42     0.00       4.60        1.42
# SNPS    6.95    52.18        34.32    3.37     0.03       4.04         NaN
# TEL     3.69      NaN        20.61     NaN     0.45      -0.35        1.90
# TXN    16.86    26.38        25.77    2.64     0.89       5.33        2.56
# TYL     7.34    72.77        57.47    7.28     0.00       4.62         NaN
# VRSN     NaN    30.31        34.91    3.79      NaN       6.74         NaN
# V      13.45    39.05        35.25    4.45     0.69       5.26        0.58
# WDC     1.18      NaN         5.99     NaN     1.00      -0.85         NaN
# WU       NaN    15.48        11.27    1.79      NaN       1.45        4.01
# XRX     0.73    10.93         8.48     NaN     0.73       1.73        5.29
# XLNX   10.78    40.25        30.50    5.38     0.86       2.56        1.48
# ZBRA    7.59    28.23        18.74    2.82     0.68       9.12         NaN
#
#         ROE    ROI
# ACN    32.4   33.9
# ADBE   35.1   20.6
# AMD    21.5   12.4
# AKAM   14.7    9.0
# APH    24.7   15.6
# ADI     9.5    9.2
# ANSS   12.1   11.2
# AAPL   70.7   26.9
# AMAT   35.9   20.4
# ANET   26.3   27.8
# ADSK -379.9   14.0
# ADP    44.9   30.8
# AVGO   10.7    6.8
# BR     38.4   16.2
# CDNS   50.8   40.9
# CDW    77.5   22.2
# CSCO   31.2   20.7
# CTXS  249.5   44.8
# CTSH   15.0   15.4
# GLW     1.0    5.7
# DXC   -86.0  -35.3
# FFIV   16.6   23.0
# FIS     0.1    1.2
# FISV    2.6    2.5
# FLT    22.9   12.0
# FLIR    9.3    8.0
# FTNT   45.6   21.6
# IT     25.6   10.4
# GPN     1.4    1.9
# HPE     0.0    5.3
# ...     ...    ...
# MA    128.9   55.6
# MXIM   38.6   25.0
# MCHP   11.7    7.0
# MU      6.1   15.0
# MSFT   39.5   23.1
# MSI   -94.1   31.3
# NTAP    NaN   42.4
# NLOK    NaN    8.2
# NVDA   26.9   18.8
# ORCL   71.4   14.3
# PAYX   41.3   31.3
# PAYC   32.2   32.3
# PYPL   15.4   10.0
# QRVO    9.1    4.6
# QCOM   69.6   21.3
# CRM     6.8   -0.7
# STX    55.9   21.3
# NOW    35.1   21.3
# SWKS   18.6   20.7
# SNPS   14.7   12.0
# TEL    -1.0   13.7
# TXN    60.4   34.1
# TYL    11.3    8.8
# VRSN  -54.9  305.7
# V      38.3   26.5
# WDC    -2.6    0.7
# WU   -862.9   37.5
# XRX     NaN    7.0
# XLNX   25.9   21.1
# ZBRA   28.0   20.5
#
# [71 rows x 9 columns]

# %% [markdown]
# ### To CSV

# %%
data.to_csv(r'C:\Users\Administrator\Desktop\DATA\Python Test Data\stock_recomm.csv')
